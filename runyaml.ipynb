# %%
# %%bash
#
# cd /project/chihway/junzhou
#
# source "$(./miniconda3/bin/conda info --base)/etc/profile.d/conda.sh"
#
# conda activate cocoa
#
# cd ./cocoa_approx/Cocoa
#
# source ./start_cocoa.sh
#
# export OMP_NUM_THREADS=8; export OMP_PROC_BIND=close; export OMP_PLACES=cores; export OMP_DYNAMIC=FALSE
#
# mpirun -n 1 --oversubscribe --mca pml ^ucx --mca btl vader,tcp,self \
#    --bind-to core:overload-allowed --mca mpi_yield_when_idle 1 --report-bindings  \
#    --rank-by slot --map-by numa:pe=${OMP_NUM_THREADS} \
#    cobaya-run ./projects/lsst_fourier/lsst_limber+noRSD+takahashi_evaluate.yaml -f
# Out:
#         (start_all_projects.sh) warning:  DIR DOES NOT EXIST (/project/chihway/junzhou/cocoa_approx/Cocoa/projects/fisher/scripts)
#         (create_link_all_projects.sh) warning:  DIR DOES NOT EXIST (/project/chihway/junzhou/cocoa_approx/Cocoa/projects/fisher/interface)
#         (create_link_all_projects.sh) warning:  DIR DOES NOT EXIST (/project/chihway/junzhou/cocoa_approx/Cocoa/projects/fisher/likelihood)
#         (create_link_all_projects.sh) warning:  DIR DOES NOT EXIST (/project/chihway/junzhou/cocoa_approx/Cocoa/projects/fisher/data)
# --------------------------------------------------------------------------
# PRTE has detected that the head of the session directory tree (where
# scratch files and shared memory backing storage will be placed)
# resides on a shared file system:
#
#    Directory: /home/junzhou
#    File system type: gpfs
#
# For performance reasons, it is strongly recommended that the session
# ...

# %%
# %%bash
#
# cd /home/junzhou
#
# source "$(/home/junzhou/miniconda3/bin/conda info --base)/etc/profile.d/conda.sh"
#
# conda activate cocoa
#
# cd ./cocoa/Cocoa
#
# source start_cocoa.sh
#
# export OMP_NUM_THREADS=2; export OMP_PROC_BIND=close; export OMP_PLACES=cores; export OMP_DYNAMIC=FALSE
#
# mpirun -n 4 --oversubscribe --mca pml ^ucx --mca btl vader,tcp,self \
#    --bind-to core:overload-allowed --mca mpi_yield_when_idle 1 --report-bindings  \
#    --rank-by slot --map-by numa:pe=${OMP_NUM_THREADS} \
#    cobaya-run ./projects/pe/fiducial_MCMC.yaml -f
# Out:
# [JZCLUSTER:28179] Rank 0 bound to package[0][core:0-1]
# [JZCLUSTER:28179] Rank 1 bound to package[0][core:2-3]
# [JZCLUSTER:28179] Rank 2 bound to package[0][core:4-5]
# [JZCLUSTER:28179] Rank 3 bound to package[0][core:6-7]
# [0 : output] Output to be read-from/written-into folder './projects/pe/chains', with prefix 'fiducial_MCMC'
# [0 : output] Found existing info files with the requested output prefix: './projects/pe/chains/fiducial_MCMC'
# [0 : output] Will delete previous products ('force' was requested).
#
# Classy could not be found in your system.
# Here are some suggestions:
#
# 	 -Download the Class from class-code.net and install it
# 	  together with its wrapper classy (type 'make' instead of
# 	  'make class'
# 	 -If you know that Class is installed on your system
# 	  and yet classy could not be installed, try re-compiling
# 	  Class with just ''make'' instead of ''make class''
# NOTICE: Even without classy you can still use EuclidEmulator2
# ...

# %%
# %%bash
#
# cd /project/chihway/junzhou
#
# source "$(./miniconda3/bin/conda info --base)/etc/profile.d/conda.sh"
#
# conda activate cocoa
#
# cd ./cocoa/Cocoa
#
# source start_cocoa.sh
#
# export OMP_NUM_THREADS=8; export OMP_PROC_BIND=close; export OMP_PLACES=cores; export OMP_DYNAMIC=FALSE
#
#
# mpirun -n 1 --oversubscribe --mca pml ^ucx --mca btl vader,tcp,self \
#    --bind-to core:overload-allowed --mca mpi_yield_when_idle 1 --report-bindings  \
#    --rank-by slot --map-by numa:pe=${OMP_NUM_THREADS} \
#    cobaya-run ./projects/pe/wCDM_fiducial_EVALUATE.yaml -f
# Out:
# --------------------------------------------------------------------------
# PRTE has detected that the head of the session directory tree (where
# scratch files and shared memory backing storage will be placed)
# resides on a shared file system:
#
#    Directory: /home/junzhou
#    File system type: gpfs
#
# For performance reasons, it is strongly recommended that the session
# directory be located on a local file system. This can be controlled by
# setting the system temporary directory to be used by PRTE using either
# the TMPDIR envar or the "prte_tmpdir_base" MCA param.
#
# If you need the temporary directory to be different on remote nodes
# from the local one where prterun is running (e.g., when a login node is
# being employed), then you can set the local temporary directory using
# the "prte_local_tmpdir_base" MCA param and the one to be used on all
# other nodes using the "prte_remote_tmpdir_base" param.
#
# ...

# %%
# %%bash
#
# cd /project/chihway/junzhou
#
# source "$(./miniconda3/bin/conda info --base)/etc/profile.d/conda.sh"
#
# conda activate cocoa
#
# cd ./cocoa/Cocoa
#
# source start_cocoa.sh
#
# export OMP_NUM_THREADS=8; export OMP_PROC_BIND=close; export OMP_PLACES=cores; export OMP_DYNAMIC=FALSE
#
# mpirun -n 1 --oversubscribe --mca pml ^ucx --mca btl vader,tcp,self \
#    --bind-to core:overload-allowed --mca mpi_yield_when_idle 1 --report-bindings  \
#    --rank-by slot --map-by numa:pe=${OMP_NUM_THREADS} \
#    cobaya-run ./projects/pe/w0waCDM_fiducial_EVALUATE.yaml -f
# Out:
# --------------------------------------------------------------------------
# PRTE has detected that the head of the session directory tree (where
# scratch files and shared memory backing storage will be placed)
# resides on a shared file system:
#
#    Directory: /home/junzhou
#    File system type: gpfs
#
# For performance reasons, it is strongly recommended that the session
# directory be located on a local file system. This can be controlled by
# setting the system temporary directory to be used by PRTE using either
# the TMPDIR envar or the "prte_tmpdir_base" MCA param.
#
# If you need the temporary directory to be different on remote nodes
# from the local one where prterun is running (e.g., when a login node is
# being employed), then you can set the local temporary directory using
# the "prte_local_tmpdir_base" MCA param and the one to be used on all
# other nodes using the "prte_remote_tmpdir_base" param.
#
# ...
